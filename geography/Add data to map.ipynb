# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

ax = plt.axes(projection=ccrs.PlateCarree())
ax.stock_img() #layred

nairobi_lon, nairobi_lat = 36, -1.3
chuncheon_lon, chuncheon_lat = 127, 37  #Chuncheon is My Hometown in South Korea

plt.plot([nairobi_lon, chuncheon_lon], [ny_lat, chuncheon_lat],
         color='green', linewidth=1, marker='o',
         transform=ccrs.Geodetic(),
         )

plt.plot([nairobi_lon, chuncheon_lon], [ny_lat, chuncheon_lat],
         color='gray', linestyle='--',
         transform=ccrs.PlateCarree(),
         )

plt.text(nairobi_lon - 3, nairobi_lat - 12, 'Nairobi',
         horizontalalignment='right',
         transform=ccrs.Geodetic())

plt.text(chuncheon_lon + 3, chuncheon_lat - 12, 'ChunCheon',
         horizontalalignment='left',
         transform=ccrs.Geodetic())

plt.show()
